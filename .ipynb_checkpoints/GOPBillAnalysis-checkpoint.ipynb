# %% [markdown]
# # GOP Tax Bill -- Analyzed

# %% [markdown]
# The GOP Tax Bill was notoriously known for being long and given on such short notice before the it was called to a vote. Although some provisions have changed, it is interesting to see if we can gather important information regarding the bill through a naive analysis of the sentence structure of the bill. In this analysis we aim to determine a conclusion regarding the bill and any interesting ideas that are encompassed in the bill.
#
# Some of our implementations will include:
# * Recording counts of bigrams or instances of two nouns together
# * Reviewing the bill using unsupervised methods such as clustering
# * Examining the bill from a network standpoint where nodes are nounds and edges are verbs

# %%
import PyPDF2
import re
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import pandas as pd
from ggplot import *
import matplotlib.pyplot as plt
import string
# %matplotlib inline

# %%
#import bill
bill = open('bill_text.pdf','rb')
billReader=PyPDF2.PdfFileReader(bill)

#do a check to make sure the parser worked somewhat
print(billReader.numPages)

#create a list to hold the string versions of the bill pages excluding table of contents
billPageList=[billReader.getPage(i).extractText() for i in range(6,billReader.numPages)]
billPageList=[re.split('(?<=[A-Za-z])\.',billPageList[i].replace('\n','').replace('‘‘','').replace('—','')) for i in range(len(billPageList))]
# Out:
# 429

# %%
#Parsing of bill, cleaning basic things such as line numberings
billPageListParsed=[[re.sub(r'\(\w\)(.*)',r'\1',x) for x in page] for page in billPageList]
billPageListParsed=[[re.sub(r'\d+([A-Za-z]+)',r'\1',x) for x in page] for page in billPageListParsed]
billPageListParsed=[[re.sub(r'(.*)-\d+([a-z].*)',r'\1\2',x) for x in page] for page in billPageListParsed]
billPageListParsed=[[re.sub(r'(.*)-\d+(.*)',r'\1\2',x) for x in page] for page in billPageListParsed]
billPageListParsed=[[re.sub(r'(\D+)\d+ ([A-Za-z0-9]+)',r'\1 \2',x) for x in page] for page in billPageListParsed]
billPageListParsed=[[re.sub(r'(.*)VerDate.*',r'\1',x) for x in page][:-2] for page in billPageListParsed]
#flatten array
billPageListParsed=[y for x in billPageListParsed for y in x]

#Apparently need to keep document in string format not list-of-string format
for i in range(len(billPageListParsed)):
    if i == 0:
        continue
    elif len(billPageListParsed[i])==0:
        continue
    else:
        if re.search('[A-Z0-9]',billPageListParsed[i][0]):
            billPageListParsed[i-1]=billPageListParsed[i-1]+'.'
#billParsed=' '.join(billPageListParsed)

# %%
listOfWords=[y.replace('.','').replace(',','').replace('$','') for x.split(' ') in billParsed for y  in x]
# Out:
# '7‚‚SEC'

# %%
#count vectorize the bill such that we can find interesting insights
countVec = CountVectorizer(stop_words='english',max_df=0.01)
wordCount=countVec.fit_transform(billPageListParsed)
count=countVec.vocabulary_
count
# Out:
# {'percentbracket': 2878,
#  '525': 617,
#  'bracket': 1191,
#  'threshold': 3682,
#  '25': 347,
#  'exceeds': 1914,
#  'cent': 1270,
#  '35': 454,
#  'plus': 2949,
#  '1339': 93,
#  '39': 505,
#  'bracketthresholdamounts': 1193,
#  'percentbracketthreshold': 2879,
#  'joint': 2387,
#  'sur': 3591,
#  'viving': 3928,
#  'spouse': 3514,
#  '90': 775,
#  'head': 2179,
#  'household': 2209,
#  '67': 688,
#  '500': 594,
#  'estate': 1904,
#  'trust': 3836,
#  '550': 629,
#  '260': 359,
#  'married': 2526,
#  'fil': 2047,
#  'separate': 3383,
#  '200': 251,
#  '150': 138,
#  'inflationadjustment': 2308,
#  '2018': 267,
#  'dollar': 1741,
#  'reference': 3188,
#  'creased': 1525,
#  'to14': 3731,
#  'multiplied': 2620,
#  'cost': 1507,
#  'living': 2478,
#  'adjustment': 881,
#  'stituting': 3544,
#  'increase': 2269,
#  'sen': 3381,
#  'tence': 3631,
#  'multiple': 2619,
#  '100': 0,
#  'rounded': 3340,
#  'lowest': 2502,
#  'livingadjustment': 2479,
#  'ad': 867,
#  'justment': 2396,
#  'age': 901,
#  'cpi': 1523,
#  'normalized': 2699,
#  'specialruleforadjustments': 3465,
#  'withabaseyearafter2016': 3961,
#  'provision': 3082,
#  'provides': 3080,
#  'substi': 3573,
#  'tution': 3844,
#  'normal': 2696,
#  'ized': 2383,
#  'normalizedcpi': 2700,
#  'product': 3035,
#  'mul': 2616,
#  'tiplied': 3717,
#  'transition': 3771,
#  'transitionmultiple': 3773,
#  'tran': 3757,
#  'sition': 3434,
#  'obtained': 2717,
#  'divid': 1730,
#  'chained': 1303,
#  'consumer': 1444,
#  'price': 3016,
#  'index': 2294,
#  'urban': 3886,
#  'consumers': 1445,
#  'published': 3089,
#  'bu': 1196,
#  'reau': 3148,
#  'labor': 2398,
#  'statistics': 3537,
#  'department': 1632,
#  'values': 3901,
#  'determining': 1666,
#  'latest': 2409,
#  'publishes': 3090,
#  'initial': 2323,
#  'value': 3900,
#  'sumers': 3582,
#  'month': 2608,
#  'august': 1121,
#  'pre': 2984,
#  'ceding': 1260,
#  'determinationforcalendar': 1651,
#  'average': 1128,
#  'close': 1347,
#  'ending': 1850,
#  'revision': 3315,
#  'sumer': 3581,
#  'consistent': 1428,
#  'delayofadjustmentbasedonc': 1616,
#  'uuntil2023': 3896,
#  'notwithstanding': 2706,
#  'title': 3721,
#  'periods': 2898,
#  '2023': 273,
#  'proper': 3052,
#  'adjustments': 885,
#  'application': 1023,
#  'carry': 1227,
#  'specialrulesforcertainchildrenwith': 3482,
#  'unearnedincome': 3870,
#  'child': 1318,
#  'applies': 1060,
#  'reduced': 3176,
#  'unearned': 3869,
#  'of8': 2743,
#  'earned': 1766,
#  'of15': 2728,
#  'childtowhomsubsectionapplies': 1321,
#  'attained': 1113,
#  'parent': 2818,
#  'alive': 922,
#  'file': 2048,
#  'certainchildrenwhoseearnedin': 1281,
#  'comedoesnotexceedone': 1367,
#  'halfofindi': 2173,
#  'vidual': 3920,
#  'ssupport': 3518,
#  'child14': 1319,
#  'student': 3553,
#  '7706': 723,
#  'fined': 2057,
#  '911': 785,
#  'half': 2172,
#  'support': 3588,
#  'netunearnedincome': 2666,
#  'adjusted': 876,
#  'of11': 2724,
#  '63': 663,
#  'standard': 3526,
#  'duction': 1753,
#  'certain': 1276,
#  'depend': 1633,
#  'ents': 1875,
#  'greater': 2159,
#  'subclause': 3559,
#  'itemizes': 2375,
#  'deductions': 1589,
#  'itemized': 2374,
#  'directly': 1683,
#  'connected': 1421,
#  'production': 3036,
#  'limitationbasedontaxablein': 2450,
#  'phaseoutof12': 2919,
#  'percentrate': 2888,
#  'increased': 2270,
#  'cess': 1300,
#  '27': 368,
#  'lesser': 2425,
#  'of16': 2729,
#  'applicabledollaramount': 1014,
#  'estatesandtrusts': 1906,
#  'applicationofcurrentincometaxbrack': 1026,
#  'etstocapitalgainsbrackets': 1911,
#  'percentcapitalgainsbrack': 2880,
#  'et': 1910,
#  'taxed': 3620,
#  '1415': 116,
#  'ratethresholdsdefined': 3136,
#  'percentratethreshold': 2892,
#  'surviving': 3596,
#  '77': 721,
#  'filing': 2051,
#  '51': 600,
#  '700': 699,
#  'indi': 2296,
#  '600': 639,
#  '479': 580,
#  '452': 568,
#  '400': 511,
#  '425': 548,
#  '800': 731,
#  'to13': 3730,
#  'termined': 3651,
#  'cal': 1214,
#  'endar': 1849,
#  'applicationofsection15': 1038,
#  'rates': 3134,
#  'redesignated': 3173,
#  '6013': 641,
#  '443': 561,
#  '7851': 726,
#  'serting': 3390,
#  'applicationtothisact': 1058,
#  'internal': 2347,
#  'revenue': 3311,
#  'change': 1304,
#  'occurs': 2720,
#  '3001': 395,
#  'enactment': 1847,
#  '1002': 1,
#  'enhancement': 1858,
#  'increaseinstandarddeduction': 2279,
#  'standarddeduction': 3528,
#  'vided': 3918,
#  'deduc': 1582,
#  'means8': 2541,
#  '102': 7,
#  'quarters': 3117,
#  'unmarried': 3877,
#  'qualifying': 3114,
#  'limitationonstandarddeductionin': 2460,
#  'thecaseofcertaindependents': 3673,
#  'dependent': 1634,
#  'payer': 2851,
#  'of2': 2733,
#  'individ': 2303,
#  'ual': 3848,
#  '32': 410,
#  'certainindividuals': 1288,
#  'noteligi': 2703,
#  'bleforstandarddeduction': 1179,
#  'nonresident': 2691,
#  'alien': 919,
#  'making': 2516,
#  'months': 2610,
#  'annual': 1001,
#  'accounting': 839,
#  'common': 1376,
#  'fund': 2106,
#  'partnership': 2833,
#  'zero': 3990,
#  'unmarriedindividual': 3878,
#  'applying': 1062,
#  '237703': 334,
#  'inflationadjustments': 2309,
#  'standarddeductionamount': 3529,
#  '92019': 793,
#  'to11': 3729,
#  'gins': 2143,
#  'limitationamountincaseof': 2447,
#  'certaindependents': 1284,
#  'to23': 3735,
#  '1987': 241,
#  '81': 738,
#  '1997': 248,
#  'round': 3339,
#  'ed': 1776,
#  'minus': 2583,
#  '1398': 106,
#  'amended22': 961,
#  'basic': 1147,
#  'heading': 2180,
#  'basicstandard': 1149,
#  '3402': 443,
#  'additional': 872,
#  'aged': 902,
#  'blind': 1182,
#  '6014': 642,
#  '1003': 2,
#  'personal': 2907,
#  'exemp': 1954,
#  'repealed': 3255,
#  'definitionofdependentretained': 1609,
#  '152': 147,
#  'prior': 3023,
#  'redes': 3171,
#  'ignated': 2238,
#  'moved': 2614,
#  '1979': 238,
#  'applicationtoestatesandtrusts': 1045,
#  '26': 358,
#  'deductionforpersonal': 1587,
#  'exemption': 1959,
#  'basicdeduction': 1148,
#  'applicationtononresidentaliens': 1050,
#  'modificationofwagewithholding': 2600,
#  'conformingamendment': 1413,
#  'amended11': 949,
#  'moving': 2615,
#  'graphs': 2157,
#  'ems': 1843,
#  'left': 2422,
#  'precedes': 2985,
#  'wise': 3960,
#  'requirementofwithholding': 3283,
#  'numberofexemptions': 2712,
#  '203402': 278,
#  'amended21': 960,
#  '151': 145,
#  'facts': 2010,
#  'existing': 1971,
#  'day': 1570,
#  'ably': 823,
#  'expected': 1976,
#  'reasonably': 3146,
#  'pendent': 2865,
#  'modificationofreturnrequirement': 2599,
#  '106012': 18,
#  'of14': 2727,
#  '7703': 722,
#  'applica': 1013,
#  'ble': 1178,
#  'entitled': 1872,
#  'make': 2514,
#  'if22': 2236,
#  'combined': 1366,
#  'home': 2202,
#  'scribed': 3368,
#  '1563': 157,
#  'bankruptcyestates': 1140,
#  '6012': 640,
#  '2163': 301,
#  '29151': 388,
#  'subsections': 3566,
#  'son': 3452,
#  'stepson': 3543,
#  'daughter': 1569,
#  'stepdaughter': 3542,
#  'unless': 3876,
#  'flush': 2063,
#  'matter': 2533,
#  'number': 2711,
#  'individuals': 2304,
#  'allowance': 935,
#  'emptions': 1842,
#  'dependents': 1635,
#  '30': 393,
#  'al': 918,
#  'lowed': 2500,
#  'lowance': 2499,
#  'exemptions': 1965,
#  '42': 533,
#  'amended9': 969,
#  'comma': 1368,
#  '72': 707,
#  '177706': 194,
#  '105': 14,
#  'amended19': 957,
#  '125': 66,
#  '132': 90,
#  'amended5': 965,
#  '162': 167,
#  '137706': 101,
#  '170': 180,
#  '187706': 213,
#  '172': 184,
#  '220': 307,
#  'ent': 1862,
#  '223': 316,
#  '401': 516,
#  '402': 517,
#  '157706': 158,
#  '501': 597,
#  '529': 619,
#  '217706': 303,
#  '28': 378,
#  '703': 701,
#  '29': 385,
#  '904': 778,
#  '931': 794,
#  'relat': 3229,
#  '33': 422,
#  'amended13': 951,
#  '34': 441,
#  '1212': 54,
#  '642': 670,
#  '1361': 96,
#  '27706': 376,
#  '36': 466,
#  '1402': 109,
#  '37': 479,
#  '77706': 724,
#  '38': 495,
#  '1463': 130,
#  '40': 510,
#  '41': 523,
#  'amended1': 947,
#  'language': 2400,
#  'lowing': 2503,
#  '43': 552,
#  'provisions': 3083,
#  '44': 557,
#  '6103': 653,
#  'pendents': 2867,
#  '45': 565,
#  '6213': 660,
#  '46': 570,
#  '6334': 666,
#  'exemptamount': 1956,
#  'exempt': 1955,
#  'divided': 1731,
#  '52': 612,
#  'verifiedstatement': 3910,
#  'submits': 3563,
#  'written': 3972,
#  'properly': 3053,
#  'verified': 3909,
#  'statement': 3534,
#  'specifying': 3505,
#  'necessary': 2637,
#  'determine': 1660,
#  'mar': 2520,
#  'ried': 3318,
#  '47': 576,
#  '48': 581,
#  '49': 584,
#  '50': 593,
#  'to9': 3738,
#  '1004': 3,
#  'maximum': 2534,
#  'viduals': 3921,
#  'reductionintaxtoachieve25': 3184,
#  'maximumrate': 2535,
#  'of13': 2726,
#  'gain': 2118,
#  'of21': 2735,
#  'of22': 2736,
#  'qualifiedbusinessincome': 3103,
#  'of12': 2725,
#  'derived': 1642,
#  'passive': 2840,
#  'active': 860,
#  'busi': 1200,
#  'ness': 2648,
#  'of19': 2732,
#  'carryover': 1239,
#  'determinationofnetbusinessincomeor': 1654,
#  'ac': 827,
#  'tivity': 3726,
#  'appropriately': 1068,
#  'netting': 2664,
#  'items': 2376,
#  'wages': 3934,
#  '3401': 442,
#  'payments': 2854,
#  '707': 702,
#  'directors': 1684,
#  'fees': 2029,
#  'exceptionforcertaininvestment': 1921,
#  'relateditems': 3231,
#  'count': 1509,
#  'short': 3415,
#  'long': 2491,
#  'dividend': 1732,
#  'equivalent': 1881,
#  'lieu': 2439,
#  'dividends': 1733,
#  '954': 800,
#  'inter': 2344,
#  'est': 1898,
#  'allocable': 925,
#  '9954': 817,
#  'attrib': 1117,
#  'utable': 3891,
#  'notional': 2705,
#  'principal': 3021,
#  'contracts': 1459,
#  'entered': 1864,
#  'transactions': 3760,
#  '131221': 88,
#  'annuity': 1007,
#  'connection': 1423,
#  'applicationofrestrictionsapplica': 1036,
#  'bletodeterminingtaxableincome': 1181,
#  'affects': 896,
#  'determination': 1650,
#  'carryoverbusinessloss': 1240,
#  'passiveandactivebusinessactivity': 2841,
#  'passivebusinessactivity': 2842,
#  'gard': 2124,
#  'activebusinessactivity': 861,
#  'businessactivity': 1201,
#  '469': 575,
#  'involves': 2359,
#  'conduct': 1408,
#  'capitalpercentage': 1223,
#  'increasedpercentageforcapital': 2275,
#  'tensivebusinessactivities': 3633,
#  'elects': 1812,
#  'subsequent': 3567,
#  'later': 2407,
#  'extensions': 1996,
#  'revoked': 3316,
#  'treatmentofspecifiedserviceac': 3816,
#  'tivities': 3725,
#  'tive': 3722,
#  'ap': 1009,
#  'plied': 2940,
#  'exceptionforcapital': 1918,
#  'intensive': 2340,
#  'specifiedserviceactivities': 3502,
#  'specifiedserviceactivity': 3503,
#  'activ': 859,
#  'ity': 2379,
#  'involving': 2360,
#  'performance': 2893,
#  'services': 3395,
#  '1202': 49,
#  'vesting': 3913,
#  'trading': 3753,
#  'dealing': 1572,
#  'securities': 3377,
#  '475': 579,
#  'ests': 1909,
#  'commodities': 1373,
#  '22475': 321,
#  'reductionincapitalpercentagein': 3183,
#  'certaincases': 1280,
#  'quotient': 3124,
#  'of4': 2740,
#  'mining': 2581,
#  'applicablepercentage': 1020,
#  'centage': 1271,
#  'great': 2158,
#  'er': 1882,
#  'specifiedreturnoncapital': 3501,
#  'spect': 3506,
#  'of24': 2738,
#  'deemed': 1590,
#  'asset': 1094,
#  'balance': 1139,
#  'accrued': 843,
#  'deemedrateofreturn': 1593,
#  'federal': 2026,
#  'ends': 1851,
#  'points': 2953,
#  'assetbalance': 1095,
#  'ferred': 2033,
#  'equals': 1877,
#  '168': 177,
#  '179': 197,
#  'applicationtoactivitiescar': 1039,
#  'riedonthroughpartnershipsandscor': 3319,
#  'porations': 2962,
#  'carried': 1226,
#  'distributive': 1723,
#  'rata': 3129,
#  'nership': 2646,
#  'issue': 2369,
#  'guidance': 2169,
#  'propriate': 3063,
#  'includ': 2259,
#  'ensures': 1861,
#  'treats': 3821,
#  'activities': 864,
#  'single': 3427,
#  'activi': 863,
#  'ties': 3690,
#  '414': 529,
#  'references': 3189,
#  'context': 1450,
#  'clearly': 1343,
#  'cates': 1253,
#  'percentrateforcertaindividendsof': 2891,
#  'realestateinvestmenttrustsandcoopera': 3143,
#  'tives': 3724,
#  'percentrateforcertaindivi': 2890,
#  'dendsofrealestateinvestmenttrustsand': 1624,
#  'cooperatives': 1480,
#  'unrecaptured': 3881,
#  'specifieddividendincome': 3497,
#  'ceived': 1265,
#  'real': 3142,
#  'investment': 2355,
#  'nei': 2642,
#  'ther21': 3676,
#  '852': 762,
#  'includible': 2263,
#  'organization': 2783,
#  '1381': 103,
#  'netearningsfromself': 2654,
#  'employment': 1838,
#  'applicationtolaborpercentageof': 1048,
#  'distributiveandproratashares': 1724,
#  'car': 1224,
#  'distributed': 1718,
#  '702': 700,
#  'member': 2555,
#  'dis': 1685,
#  'tributive': 3829,
#  'mem': 2554,
#  'ber': 1167,
#  'distrib': 1716,
#  'uted': 3892,
#  'nonseparately': 2693,
#  'computed': 1398,
#  '1366': 97,
#  'ordinary': 2778,
#  'com': 1364,
#  'puted': 3100,
#  'laborpercentage': 2399,
#  'expressed': 1983,
#  'pressed': 3008,
#  'decimal': 1579,
#  'adjustmentforscorporation': 884,
#  'applicationtorentalincome': 1056,
#  'applicationtolimitedpartners': 1049,
#  'clericalamendment': 1344,
#  'transitionrule': 3775,
#  'includes': 2261,
#  'adjusted4': 877,
#  'achieve': 849,
#  'effective': 1788,
#  'manner': 2519,
#  'reducing': 3179,
#  'reduction': 3180,
#  'bears': 1155,
#  'proportion': 3061,
#  'days': 1571,
#  '182018': 208,
#  'entire': 1868,
#  '1005': 4,
#  'conforming': 1412,
#  'sim': 3422,
#  'plification': 2943,
#  'amendmentsrelatedtomodificationof': 971,
#  '53': 620,
#  'livingadjustmentde': 2480,
#  'specialrulewherebasepe': 3491,
#  'riodendsinacalendaryearother': 3325,
#  'thanor1984': 3671,
#  'base': 1141,
#  '171984': 183,
#  '2008': 256,
#  '231992': 331,
#  '12016': 48,
#  '2001': 252,
#  '51992': 611,
#  '82016': 748,
#  '2012': 261,
#  '1992': 244,
#  '152012': 148,
#  'amended18': 956,
#  '231': 326,
#  '55': 628,
#  'places': 2929,
#  'pears': 2863,
#  'cuts': 1558,
#  'jobs': 2386,
#  '91997': 790,
#  'mined21': 2578,
#  '222016': 313,
#  'thereof23': 3678,
#  '56': 631,
#  '2003': 253,
#  'march': 2521,
#  'publish': 3088,
#  'june': 2392,
#  '430': 553,
#  'vii': 3922,
#  '2009': 257,
#  '162009': 168,
#  '512': 607,
#  '1994': 245,
#  '513': 609,
#  '71': 704,
#  '831': 750,
#  '2013': 263,
#  '141992': 119,
#  '172016': 185,
#  '2007': 255,
#  '2004': 254,
#  'debt': 1574,
#  'instrument': 2333,
#  'arising': 1077,
#  'sale': 3353,
#  '242016': 338,
#  '59': 634,
#  'adjusteddollaramounts': 879,
#  'rounding': 3341,
#  'nearest': 2635,
#  '2010': 259,
#  '111992': 33,
#  '181992': 205,
#  '2503': 351,
#  '601992': 644,
#  '4161': 531,
#  '102016': 8,
#  '4261': 549,
#  'nonindexed': 2683,
#  'fore': 2067,
#  '182016': 206,
#  '61': 651,
#  'amended3': 963,
#  '6323': 665,
#  '1996': 247,
#  '1998': 249,
#  '1999': 250,
#  '6601': 678,
#  '6651': 679,
#  '6721': 690,
#  'amended16': 954,
#  '212016': 290,
#  '6722': 691,
#  'amended23': 962,
#  '32016': 414,
#  '6652': 680,
#  '92013': 792,
#  '6695': 685,
#  '6698': 686,
#  '211': 287,
#  '222013': 312,
#  '64': 667,
#  '6699': 687,
#  '7345': 709,
#  '2015': 265,
#  '91992': 789,
#  '7430': 712,
#  '1995': 246,
#  '161992': 166,
#  'text': 3669,
#  '7872': 728,
#  '65': 676,
#  'loan': 2482,
#  'to5': 3736,
#  '112016': 35,
#  'adjusteddollaramount': 878,
#  '162018': 169,
#  'otherconformingamendments': 2790,
#  'aa': 818,
#  'highest': 2189,
#  '511': 606,
#  '641': 669,
#  'set': 3397,
#  'forth': 2086,
#  '181': 200,
#  '646': 674,
#  'lows': 2504,
#  'taxationofincomeoftrust': 3617,
#  'im': 2244,
#  'posed': 2969,
#  'electing': 1801,
#  'settlement': 3400,
#  '685': 694,
#  'whichever': 3955,
#  'brackets': 1192,
#  '131': 84,
#  'fourth': 2090,
#  '68': 692,
#  '3406': 447,
#  'thetax': 3681,
#  'bšsimplification': 1212,
#  'form': 2078,
#  'family': 2017,
#  'credits': 1537,
#  '1101': 26,
#  'increaseincreditamountandadditionof': 2278,
#  'otherdependents': 2793,
#  '69': 695,
#  '300': 394,
#  'amended8': 968,
#  'given': 2145,
#  'certainindividualsnottreated': 1289,
#  'asdependents': 1092,
#  '70': 698,
#  'redesig': 3172,
#  'nated': 2629,
#  'terms': 3655,
#  'quali': 3101,
#  'fying': 2114,
#  'andfamily': 997,
#  'eliminationofmarriagepenalty': 1828,
#  '1924': 225,
#  'amended20': 959,
#  '110': 25,
#  '230': 325,
#  '75': 714,
#  'pe': 2861,
#  'riod': 3323,
#  'creditrefundableupto': 1536,
#  'determined10': 1661,
#  '212017': 291,
#  '1102': 27,
#  'nonrefundable': 2690,
#  'repealofsection22': 3261,
#  '86': 766,
#  '73': 708,
#  'permanentandtotaldisabilityde': 2901,
#  'permanently': 2902,
#  'totally': 3747,
#  'disabled': 1687,
#  'unable': 3855,
#  'engage': 1853,
#  'substantial': 3570,
#  'gainful': 2120,
#  'medically': 2546,
#  'minable': 2575,
#  'physical': 2923,
#  'mental': 2559,
#  'impairment': 2247,
#  'result': 3305,
#  'death': 1573,
#  'lasted': 2403,
#  'continuous': 1456,
#  'considered': 1425,
#  'furnishes': 2111,
#  'proof': 3050,
#  'existence': 1970,
#  'times': 3697,
#  'require': 3280,
#  '415': 530,
#  '422': 545,
#  'repealofsection23': 3262,
#  '74': 710,
#  'terminationofsection25': 3649,
#  '3601': 468,
#  'termination': 3641,
#  'mortgage': 2613,
#  'cer': 1275,
#  'tificate': 3691,
#  'issued': 2370,
#  'repealofsectiond': 3264,
#  '1016': 5,
#  '6501': 677,
#  'vehicles': 3905,
#  'placed': 2927,
#  '631': 664,
#  '1103': 28,
#  'refundable': 3203,
#  'program': 3044,
#  'integrity': 2339,
#  'socialsecuritynumberrequiredtoclaim': 3443,
#  'therefundableportionofthechildtaxcred': 3677,
#  'identificationrequirement': 2227,
#  'cial': 1325,
#  'security': 3378,
#  'jointreturns': 2391,
#  'requirement': 3282,
#  'met': 2568,
#  'social': 3440,
#  'included': 2260,
#  'turn': 3842,
#  'socialsecuritynumber': 3441,
#  'se': 3369,
#  'curity': 1548,
#  'administration': 886,
#  'citizen': 1333,
#  'pursuant': 3096,
#  'relates': 3235,
#  '205': 281,
#  'omissionstreatedasmathematicalor': 2757,
#  'clericalerror': 1345,
#  'omission': 2756,
#  'correct': 1501,
#  'secu': 3374,
#  'rity': 3330,
#  'cred': 1529,
#  'tin': 3699,
#  '2024': 274,
#  'cluded': 1355,
#  'identifica': 2225,
#  'tionrequirements': 3712,
#  'general': 2132,
#  'identificationrequirements': 2228,
#  'socialsecuritynumbermustbepro': 3442,
#  'identification': 2226,
#  'place': 2926,
#  'appears': 1011,
#  'omissiontreatedasmathematicalor': 2758,
#  'amend': 946,
#  'individualsprohibitedfromengagingin': 2305,
#  'employmentinunitedstatesnoteligiblefor': 1839,
#  'earnedincometaxcredit': 1767,
#  'ed16': 1778,
#  '78': 725,
#  'cšsimplification': 1561,
#  'reform': 3200,
#  'education': 1782,
#  'incentives': 2254,
#  '1201': 47,
#  'american': 977,
#  'opportunity': 2772,
#  'tuition': 3840,
#  'furnished': 2110,
#  'eligible': 1818,
#  'academic': 829,
#  'twice': 3846,
#  '79': 729,
#  'portionofcreditrefundable': 2966,
#  'limitationbasedonmodifiedadjusted': 2449,
#  'grossincome': 2161,
#  'ratio': 3138,
#  'provi': 3073,
#  'sions': 3430,
#  'as18': 1089,
#  'modified': 2602,
#  '80': 730,
#  'modifiedadjustedgrossincome': 2603,
#  'excluded': 1944,
#  '933': 795,
#  'otherlimitations': 2794,
#  'creditallowedonlyfortaxable': 1531,
#  'creditallowedonlyforfirst5': 1530,
#  'yearsofpostsecondaryeducation': 3986,
#  'completed': 1388,
#  'postsecondary': 2979,
#  'educational': 1783,
#  'institution': 2331,
#  'fifthyearlimitations': 2046,
#  'fifth': 2045,
#  'definitions': 1610,
#  'eligiblestudent': 1823,
#  'meets': 2549,
#  'requirements': 3284,
#  '20484': 280,
#  'higher': 2188,
#  '1091': 22,
#  '225': 322,
#  '82': 747,
#  'carrying': 1238,
#  'work': 3970,
#  'load': 2481,
#  'course': 1513,
#  'study': 3555,
#  'pursuing': 3097,
#  'qualifiedtuitionandrelatedex': 3112,
#  'penses': 2874,
#  'materials': 2531,
#  'enroll': 1859,
#  'attendance': 1115,
#  'courses': 1514,
#  'instruction': 2332,
#  'institu': 2330,
#  'exceptionforeducationinvolv': 1924,
#  'ingsports': 2319,
#  'sports': 3513,
#  'games': 2123,
#  'hobbies': 2195,
#  'degree': 1615,
#  'exceptionfornonacademic': 1926,
#  'athletic': 1109,
#  'unrelated': 3882,
#  'aca': 828,
#  'demic': 1619,
#  'eligibleeducationalinstitution': 1820,
#  '1965': 236,
#  '71088': 705,
#  'participate': 2824,
#  'specialrules': 3480,
#  'cludes': 1356,
#  'identi': 2224,
#  'fication': 2039,
#  'identifying': 2230,
#  'num': 2710,
#  '84': 753,
#  'adjustmentforcertainscholar': 882,
#  'ships': 3413,
#  'benefit': 1164,
#  'allo': 923,
#  'cable': 1213,
#  'as14': 1086,
#  'scholarship': 3364,
#  'cludable': 1353,
#  '117': 41,
#  'assistance': 1098,
#  'gift': 2137,
#  'quest': 3119,
#  'devise': 1668,
#  'inheritance': 2320,
#  'edu': 1781,
#  'cational': 1254,
#  'enrollment': 1860,
#  'stitution': 3545,
#  'excludable': 1943,
#  'law': 2416,
#  'treatmentofexpensespaidbyde': 3807,
#  'treatmentofcertainprepay': 3798,
#  'ments': 2561,
#  'denialofdoublebenefit': 1629,
#  'nocreditformarriedindividuals': 2676,
#  'filingseparatereturns': 2052,
#  '37703': 492,
#  'nonresidentaliens': 2692,
#  'dividual': 1735,
#  'resident': 3295,
#  'restrictionsontaxpayerswhoim': 3304,
#  'properlyclaimedcreditinprioryear': 3054,
#  'taxpayersmakingpriorfraudu': 3626,
#  'lentorrecklessclaims': 2424,
#  'disallowance': 1688,
#  'disallowanceperiod': 1691,
#  'is22': 2364,
#  'recent': 3158,
#  'final': 2053,
#  'mination': 2576,
#  'claim': 1335,
#  'fraud': 2092,
#  'reckless': 3160,
#  'intentional': 2343,
#  'disregard': 1712,
#  'taxpayersmakingimproper': 3625,
#  'priorclaims': 3024,
#  'denied': 1630,
#  'deficiency': 1603,
#  'proce': 3028,
#  ...}

# %%
#count words associated with wealthy americans
wealthyDictionary={'estate':0,'trust':0,'corporation':0}
for word in count:
    if 'estate' in word.lower(): 
        wealthyDictionary['estate']+=count[word]
    if'trust' in word.lower(): 
        wealthyDictionary['trust']+=count[word]
    if 'corporation' in word.lower():
        wealthyDictionary['corporation']+=count[word]
wealthyDictionary
# Out:
# {'corporation': 52551, 'estate': 16745, 'trust': 27378}

# %%
#count words associated average americans
averageDictionary={'parent':0,'child':0,'dependent':0,'small_business':0}
for word in count:
    if 'parent' in  word.lower():
        averageDictionary['parent']+=count[word]
    if 'child'  in word.lower() or 'children' in word.lower():
        averageDictionary['child']+=count[word]
    if 'dependent' in word.lower():
        averageDictionary['dependent']+=count[word]
    if 'small' in word.lower() and 'business' in word.lower():
        averageDictionary['small_business']+=count[word]
averageDictionary
# Out:
# {'child': 25254, 'dependent': 22047, 'parent': 4892, 'small_business': 3439}

# %%
#special industries
industryDictionary={'pharmaceuticals':0,'agriculture':0,'alternative_energy':0,'oil_and_gas':0,'subsidy':0}
for word in count:
    if 'pharma' in word.lower():
        industryDictionary['pharmaceuticals']=+count[word]
    if 'agri' in word.lower() or 'farm' in word.lower() or 'crop' in word.lower():
        industryDictionary['agriculture']+=count[word]
    if 'wind' in word.lower() or 'solar' in word.lower():
        industryDictionary['alternative_energy']+=count[word]
    if 'oil' in word.lower() or 'gas' in word.lower():
        industryDictionary['oil_and_gas']+=count[word]
    if 'subsi' in word.lower():
        industryDictionary['subsidy']+=count[word]
industryDictionary
# Out:
# {'agriculture': 15062,
#  'alternative_energy': 22978,
#  'oil_and_gas': 4878,
#  'pharmaceuticals': 0,
#  'subsidy': 0}

# %%
#Powerful Visualization 1: Corporations vs. Small Business

values=[wealthyDictionary['corporation'],averageDictionary['small_business']]
index=['corporation','small_business']
width=1/2
plt.figure(figsize=(10,8))
plt.bar(index,values,width)
plt.xlabel('Type of Business')
plt.ylabel('Count')
plt.title('Incidence of Business Type in the GOP Tax Bill')
# Out:
# Text(0.5,1,'Incidence of Business Type in the GOP Tax Bill')

# %% [markdown]
# Some interesting notes about the bill already. The bill is currently in an imperfect parsed format where words can appear in a string of words with no spaces, i.e. 'hellomynameisbob', and 'hello', 'name' and 'bob' are all separate words. The words associated with wealthy or big corporations are all between $10^5$ and $10^6$ however, words associated with the average american don't come close to $10^5$
